# %% [markdown]
# # Synthitic Arabic datasets generated for buil

# %%
# !python3 tool/create_dataset.py --out /home/niddal/Desktop/PhD_projects/crnn_pytorch-new/lmdb/Ar_Tr \
--file /home/niddal/Desktop/PhD_projects/Arabic-text-recognition-master/data/Ar_200k/Train.txt \
--folder /home/niddal/Desktop/PhD_projects/Arabic-text-recognition-master/data/
# Out:
# Written 1000 / 586735
# Written 2000 / 586735
# Written 3000 / 586735
# Written 4000 / 586735
# Written 5000 / 586735
# Written 6000 / 586735
# Written 7000 / 586735
# Written 8000 / 586735
# Written 9000 / 586735
# Written 10000 / 586735
# Written 11000 / 586735
# Written 12000 / 586735
# Written 13000 / 586735
# Written 14000 / 586735
# Written 15000 / 586735
# Written 16000 / 586735
# Written 17000 / 586735
# Written 18000 / 586735
# Written 19000 / 586735
# Written 20000 / 586735
# Written 21000 / 586735
# Written 22000 / 586735
# Written 23000 / 586735
# Written 24000 / 586735
# Written 25000 / 586735
# Written 26000 / 586735
# Written 27000 / 586735
# Written 28000 / 586735
# Written 29000 / 586735
# Written 30000 / 586735
# Written 31000 / 586735
# Written 32000 / 586735
# Written 33000 / 586735
# Written 34000 / 586735
# Written 35000 / 586735
# Written 36000 / 586735
# Written 37000 / 586735
# Written 38000 / 586735
# Written 39000 / 586735
# Written 40000 / 586735
# ...

# %%
# !python3 tool/create_dataset.py --out /home/niddal/Desktop/PhD_projects/crnn_pytorch-new/lmdb/Ar_Val \
--file /home/niddal/Desktop/PhD_projects/Arabic-text-recognition-master/data/Ar_200k/validation.txt \
--folder /home/niddal/Desktop/PhD_projects/Arabic-text-recognition-master/data/
# Out:
# Written 1000 / 184996
# Written 2000 / 184996
# Written 3000 / 184996
# Written 4000 / 184996
# Written 5000 / 184996
# Written 6000 / 184996
# Written 7000 / 184996
# Written 8000 / 184996
# Written 9000 / 184996
# Written 10000 / 184996
# Written 11000 / 184996
# Written 12000 / 184996
# Written 13000 / 184996
# Written 14000 / 184996
# Written 15000 / 184996
# Written 16000 / 184996
# Written 17000 / 184996
# Written 18000 / 184996
# Written 19000 / 184996
# Written 20000 / 184996
# Written 21000 / 184996
# Written 22000 / 184996
# Written 23000 / 184996
# Written 24000 / 184996
# Written 25000 / 184996
# Written 26000 / 184996
# Written 27000 / 184996
# Written 28000 / 184996
# Written 29000 / 184996
# Written 30000 / 184996
# Written 31000 / 184996
# Written 32000 / 184996
# Written 33000 / 184996
# Written 34000 / 184996
# Written 35000 / 184996
# Written 36000 / 184996
# Written 37000 / 184996
# Written 38000 / 184996
# Written 39000 / 184996
# Written 40000 / 184996
# ...

# %%
# !python3 train.py --trainroot /home/niddal/Desktop/PhD_projects/crnn_pytorch-new/lmdb/Ar_Tr/ \
--valroot /home/niddal/Desktop/PhD_projects/crnn_pytorch-new/lmdb/Ar_Val/
# Out:
# CRNN(
#   (cnn): Sequential(
#     (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU(inplace)
#     (pooling0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU(inplace)
#     (pooling1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace)
#     (conv3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu3): ReLU(inplace)
#     (pooling2): MaxPool2d(kernel_size=(2, 2), stride=(2, 1), padding=(0, 1), dilation=1, ceil_mode=False)
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...
