# %% [markdown]
# # In this experiment, we evaluate our model that trained with 200K synthetic Arabic samples

# %%
import torch
from torch.autograd import Variable
import utils
import dataset
from PIL import Image

import models.crnn as crnn
import params
import argparse
from IPython.core import display
import glob

# %%
model_path = '/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/expr/'

# net init
nclass = len(params.alphabet) + 1
model = crnn.CRNN(params.imgH, params.nc, nclass, params.nh)
# load model
print('loading pretrained model from %s' % model_path)

model.load_state_dict(torch.load(model_path))

converter = utils.strLabelConverter(params.alphabet)

transformer = dataset.resizeNormalize((100, 32))
# Out:
# loading pretrained model from /home/niddal/Desktop/PhD_projects/crnn_pytorch-new/expr/netCRNN_211_120.pth

# %%
#netCRNN_17_5000.pth

# %%
#70K+words+osn
model_path = '/home/niddal/Desktop/PhD_projects/crnn_pytorch-new//expr/Ar_500k/netCRNN_17_5000.pth'

# net init
nclass = len(params.alphabet) + 1
model = crnn.CRNN(params.imgH, params.nc, nclass, params.nh)
# load model
print('loading pretrained model from %s' % model_path)

model.load_state_dict(torch.load(model_path))

converter = utils.strLabelConverter(params.alphabet)

transformer = dataset.resizeNormalize((100, 32))
# Out:
# loading pretrained model from /home/niddal/Desktop/PhD_projects/crnn_pytorch-new//expr/Ar_500k/netCRNN_17_5000.pth

# %%
##### recognize and save results in a text file
#for img_path in glob.glob('/home/niddal/Desktop/PhD_projects/crnn_test/gt/Ar/img/*.png'):
for img_path in glob.glob('/home/niddal/Desktop/PhD_projects/Arabic-text-recognition-master/data/Ar_crnn_test/*.png'):

    image = Image.open(img_path).convert('L')
    image = transformer(image)
    image = image.view(1, *image.size())
    image = Variable(image)

    model.eval()
    preds = model(image)

    _, preds = preds.max(2)
    preds = preds.transpose(1, 0).contiguous().view(-1)
    
    with open('/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/new_200.txt','a') as fp:

        preds_size = Variable(torch.IntTensor([preds.size(0)]))
        raw_pred = converter.decode(preds.data, preds_size.data, raw=True)
        sim_pred = converter.decode(preds.data, preds_size.data, raw=False)
        display.display(display.Image(img_path))
        print('%-20s => %-20s' % (raw_pred, sim_pred))
        fp.write(img_path)
        fp.write(sim_pred)
        fp.write('\n')
    fp.close()
# Out:
# ا-للأ-------------ف--ضض--ل => الأفضل
# خ------------------------س => خس
# ا-ل-ا----------ذكككبب-ييرر => الاذكبير
# د------------------------د => دد
# ع-------------------للل--ى => على
# ف------------------------ل => فل
# ي-------------رررر-مم-لل-ي => يرملي
# االل-------------ج--ن----س => الجنس
# لل----------------------نن => لن
# خ---------------ض--وو-ماات => خضومات
# خ---------------ح-ان-ب-ت-ه => خحانبته
# ف------------------سسس-ااد => فساد
# ف---------------يييمم-ت-وو => فيمتو
# ل---------------------م--ن => لمن
# خ-------------------اانن-ه => خانه
# م----------------------د-ّ => مدّ
# اللل--------------اا-م-ا-ة => الاماة
# الل---------------ووو-ز--ن => الوزن
# االل------------ذذذككرر--ي => الذكري
# ب---------------ي--ققدد--ر => بيقدر
# ع-----------------لاااء--ج => علاءج
# م------------------------ن => من
# ت-------------------رر-تةة => ترتة
# م---------------ج-ممم--ع-ة => مجمعة
# ب-----------------ع---ي--د => بعيد
# اال-------------ش--راائيية => الشرائية
# ...

# %%
#Arabic test samples osn
# !python /home/niddal/Desktop/PhD_projects/crnn_test/config/ED.py -g=/home/niddal/Desktop/PhD_projects/crnn_test/gt/Ar/gt.txt \
-s=/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/submit.txt \
-o=/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/
# Out:
# Calculated!{"crwup": 0.2549019607843137, "tedupL": 27.684126984126973, "tedL": 27.684126984126973, "totalWords": 102, "crwN": 26.0, "crwupN": 26.0, "ted": 179.0, "tedup": 179.0, "detWords": 102, "crw": 0.2549019607843137}

# %%
#Arabic test samples net_15
# !python /home/niddal/Desktop/PhD_projects/crnn_test/config/ED.py -g=/home/niddal/Desktop/PhD_projects/crnn_test/gt/Ar/gt.txt \
-s=/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/submit.txt \
-o=/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/
# Out:
# Calculated!{"crwup": 0.4019607843137255, "tedupL": 17.640476190476186, "tedL": 17.640476190476186, "totalWords": 102, "crwN": 41.0, "crwupN": 41.0, "ted": 113.0, "tedup": 113.0, "detWords": 102, "crw": 0.4019607843137255}

# %%
#Arabic test samples Synithitic
# !python /home/niddal/Desktop/PhD_projects/crnn_test/config/ED.py -g=/home/niddal/Desktop/PhD_projects/crnn_test/gt/Ar/gt.txt \
-s=/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/submit.txt \
-o=/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/
# Out:
# Calculated!{"crwup": 0.0784313725490196, "tedupL": 46.53373015873018, "tedL": 46.53373015873018, "totalWords": 102, "crwN": 8.0, "crwupN": 8.0, "ted": 302.0, "tedup": 302.0, "detWords": 102, "crw": 0.0784313725490196}

# %%
#Arabic 200k test samples Synithitic
# !python /home/niddal/Desktop/PhD_projects/crnn_test/config/ED.py -g=/home/niddal/Desktop/PhD_projects/crnn_test/gt/Ar/gt.txt \
-s=/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/submit.txt \
-o=/home/niddal/Desktop/PhD_projects/crnn_pytorch-new/Ar200/
# Out:
# Calculated!{"crwup": 0.46078431372549017, "tedupL": 17.584920634920636, "tedL": 17.584920634920636, "totalWords": 102, "crwN": 47.0, "crwupN": 47.0, "ted": 115.0, "tedup": 115.0, "detWords": 102, "crw": 0.46078431372549017}
